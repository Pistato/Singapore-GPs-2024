# %%
# !pip install python-dotenv
# !pip install requests
# Out:
# ...
#   WARNING: Failed to write executable - trying to use .deleteme logic
# ERROR: Could not install packages due to an OSError: [WinError 2] The system cannot find the file specified: 'C:\\Python311\\Scripts\\dotenv.exe' -> 'C:\\Python311\\Scripts\\dotenv.exe.deleteme'
#
#
# [notice] A new release of pip is available: 23.0.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import requests
from dotenv import load_dotenv
import os
      
load_dotenv()

onemap_api_key = os.environ.get("ONEMAP_API_KEY")


onemap_headers = {
    'User-Agent': onemap_api_key
}

# %%
url = "https://www.onemap.gov.sg/api/common/elastic/search?searchVal=healthcare&returnGeom=Y&getAddrDetails=Y"

response = requests.request("GET", url, headers=onemap_headers)
      
print(response.text)
# Out:
# {
#   "found": 14,
#   "totalNumPages": 2,
#   "pageNum": 1,
#   "results": [
#     {
#       "SEARCHVAL": "NATIONAL HEALTHCARE GROUP POLYCLINICS (YISHUN POLYCLINIC)",
#       "BLK_NO": "2",
#       "ROAD_NAME": "YISHUN AVENUE 9",
#       "BUILDING": "NATIONAL HEALTHCARE GROUP POLYCLINICS (YISHUN POLYCLINIC)",
#       "ADDRESS": "2 YISHUN AVENUE 9 NATIONAL HEALTHCARE GROUP POLYCLINICS (YISHUN POLYCLINIC) SINGAPORE 768898",
#       "POSTAL": "768898",
#       "X": "28653.479144427",
#       "Y": "45787.2955139577",
#       "LATITUDE": "1.43035851992416",
#       "LONGITUDE": "103.839190698939"
#     },
#     {
#       "SEARCHVAL": "NATIONAL HEALTHCARE GROUP",
#       "BLK_NO": "3",
#       "ROAD_NAME": "FUSIONOPOLIS LINK",
#       "BUILDING": "NATIONAL HEALTHCARE GROUP",
#       "ADDRESS": "3 FUSIONOPOLIS LINK NATIONAL HEALTHCARE GROUP SINGAPORE 138543",
#       "POSTAL": "138543",
#       "X": "23160.4706726447",
#       "Y": "31232.4135721214",
# ...

# %%
url = "https://www.onemap.gov.sg/api/common/elastic/search?searchVal=medical&returnGeom=N&getAddrDetails=N"

response = requests.request("GET", url, headers=onemap_headers)
      
print(response.text)
# Out:
# {
#   "found": 75,
#   "totalNumPages": 8,
#   "pageNum": 1,
#   "results": [
#     {
#       "SEARCHVAL": "MEDICAL DRIVE"
#     },
#     {
#       "SEARCHVAL": "NUH MEDICAL CENTRE"
#     },
#     {
#       "SEARCHVAL": "SIAN CHAY MEDICAL INSTITUTION MARSILING BRANCH"
#     },
#     {
#       "SEARCHVAL": "CAMDEN MEDICAL CENTRE"
#     },
#     {
#       "SEARCHVAL": "SINGAPORE CHUNG HWA MEDICAL INSTITUTION"
#     },
#     {
#       "SEARCHVAL": "SINGAPORE GENERAL HOSPITAL (ALUMNI MEDICAL CENTRE)"
#     },
#     {
#       "SEARCHVAL": "THONG CHAI MEDICAL INSTITUTION ¿ SENG KANG"
#     },
#     {
#       "SEARCHVAL": "SIAN CHAY MEDICAL INSTITUTION ANG MO KIO (TRANS-CAB HQ) BRANCH"
#     },
#     {
#       "SEARCHVAL": "ALUMNI MEDICAL CENTRE"
#     },
#     {
#       "SEARCHVAL": "MOUNT ELIZABETH HOSPITAL/MEDICAL CENTRE"
#     }
#   ]
# }
